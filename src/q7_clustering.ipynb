# %% [markdown]
# This page will show
# * K means algorithm based on different factors to group the countries together

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.cluster import KMeans
